# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
ords_prods_merge = pd.read_pickle(r'C:\Users\Riley\Desktop\Data Any\DD-MM-2022-Instacart Basket Analysis\02 Data\4.3_orders_products\orders_products_merged.pkl')

# %%
path = r'C:\Users\Riley\Desktop\Data Any\DD-MM-2022-Instacart Basket Analysis'

# %%
# Create a Subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 15)

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN       196.0                1.0
# 1                  8                     NaN     14084.0                2.0
# 2                  8                     NaN     12427.0                3.0
# 3                  8                     NaN     26088.0                4.0
# 4                  8                     NaN     26405.0                5.0
#
#    reordered                             product_name  aisle_id  \
# 0        0.0                                     Soda      77.0
# 1        0.0  Organic Unsweetened Vanilla Almond Milk      91.0
# 2        0.0                      Original Beef Jerky      23.0
# 3        0.0               Aged White Cheddar Popcorn      23.0
# 4        0.0         XL Pick-A-Size Paper Towel Rolls      54.0
#
#    department_id  prices _merge
# 0            7.0     9.0   both
# 1           16.0    12.5   both
# 2           19.0     4.4   both
# 3           19.0     4.7   both
# 4           17.0     1.0   both

# %%
# Grouping Data
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              14.794925
# 2.0              17.085793
# 3.0              17.892742
# 4.0              17.880137
# 5.0              15.108513
# 6.0              15.352869
# 7.0              17.682741
# 8.0              16.496386
# 9.0              15.944846
# 10.0             20.104831
# 11.0             16.483104
# 12.0             15.614125
# 13.0             16.458631
# 14.0             17.523399
# 15.0             15.673392
# 16.0             18.012021
# 17.0             15.842139
# 18.0             19.349156
# 19.0             17.625805
# 20.0             17.113240
# 21.0             22.009038

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1.0     14.794925
# 2.0     17.085793
# 3.0     17.892742
# 4.0     17.880137
# 5.0     15.108513
# 6.0     15.352869
# 7.0     17.682741
# 8.0     16.496386
# 9.0     15.944846
# 10.0    20.104831
# 11.0    16.483104
# 12.0    15.614125
# 13.0    16.458631
# 14.0    17.523399
# 15.0    15.673392
# 16.0    18.012021
# 17.0    15.842139
# 18.0    19.349156
# 19.0    17.625805
# 20.0    17.113240
# 21.0    22.009038
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1.0              14.794925   1  99
# 2.0              17.085793   1  98
# 3.0              17.892742   1  99
# 4.0              17.880137   1  99
# 5.0              15.108513   1  99
# 6.0              15.352869   1  99
# 7.0              17.682741   1  99
# 8.0              16.496386   1  91
# 9.0              15.944846   1  99
# 10.0             20.104831   1  99
# 11.0             16.483104   1  99
# 12.0             15.614125   1  99
# 13.0             16.458631   1  99
# 14.0             17.523399   1  99
# 15.0             15.673392   1  99
# 16.0             18.012021   1  99
# 17.0             15.842139   1  99
# 18.0             19.349156   1  99
# 19.0             17.625805   1  99
# 20.0             17.113240   1  99
# 21.0             22.009038   1  97

# %%
# Transform
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2539329        1    prior             1                   2
# 2    2539329        1    prior             1                   2
# 3    2539329        1    prior             1                   2
# 4    2539329        1    prior             1                   2
# 5    2398795        1    prior             2                   3
# 6    2398795        1    prior             2                   3
# 7    2398795        1    prior             2                   3
# 8    2398795        1    prior             2                   3
# 9    2398795        1    prior             2                   3
# 10   2398795        1    prior             2                   3
# 11    473747        1    prior             3                   3
# 12    473747        1    prior             3                   3
# 13    473747        1    prior             3                   3
# 14    473747        1    prior             3                   3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN       196.0                1.0
# 1                   8                     NaN     14084.0                2.0
# 2                   8                     NaN     12427.0                3.0
# 3                   8                     NaN     26088.0                4.0
# 4                   8                     NaN     26405.0                5.0
# 5                   7                    15.0       196.0                1.0
# 6                   7                    15.0     10258.0                2.0
# 7                   7                    15.0     12427.0                3.0
# 8                   7                    15.0     13176.0                4.0
# 9                   7                    15.0     26088.0                5.0
# 10                  7                    15.0     13032.0                6.0
# 11                 12                    21.0       196.0                1.0
# 12                 12                    21.0     12427.0                2.0
# 13                 12                    21.0     10258.0                3.0
# 14                 12                    21.0     25133.0                4.0
#
#     reordered                             product_name  aisle_id  \
# 0         0.0                                     Soda      77.0
# 1         0.0  Organic Unsweetened Vanilla Almond Milk      91.0
# 2         0.0                      Original Beef Jerky      23.0
# 3         0.0               Aged White Cheddar Popcorn      23.0
# 4         0.0         XL Pick-A-Size Paper Towel Rolls      54.0
# 5         1.0                                     Soda      77.0
# 6         0.0                               Pistachios     117.0
# 7         1.0                      Original Beef Jerky      23.0
# 8         0.0                   Bag of Organic Bananas      24.0
# 9         1.0               Aged White Cheddar Popcorn      23.0
# 10        0.0                    Cinnamon Toast Crunch     121.0
# 11        1.0                                     Soda      77.0
# 12        1.0                      Original Beef Jerky      23.0
# 13        1.0                               Pistachios     117.0
# 14        0.0                    Organic String Cheese      21.0
#
#     department_id  prices _merge  max_order
# 0             7.0     9.0   both         11
# 1            16.0    12.5   both         11
# 2            19.0     4.4   both         11
# 3            19.0     4.7   both         11
# 4            17.0     1.0   both         11
# 5             7.0     9.0   both         11
# 6            19.0     3.0   both         11
# 7            19.0     4.4   both         11
# 8             4.0    10.3   both         11
# 9            19.0     4.7   both         11
# 10           14.0     4.0   both         11
# 11            7.0     9.0   both         11
# 12           19.0     4.4   both         11
# 13           19.0     3.0   both         11
# 14           16.0     8.6   both         11

# %%
# Deriving Columns
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
#4 Loyalty Flag
ords_prods_merge ['loyalty_flag']. value_counts(dropna = False)
# Out:
# Regular customer    16381472
# Loyal customer      10679578
# New customer         5580218
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1  Regular customer             1
# 1         1  Regular customer             1
# 2         1  Regular customer             1
# 3         1  Regular customer             1
# 4         1  Regular customer             1
# 5         1  Regular customer             2
# 6         1  Regular customer             2
# 7         1  Regular customer             2
# 8         1  Regular customer             2
# 9         1  Regular customer             2
# 10        1  Regular customer             2
# 11        1  Regular customer             3
# 12        1  Regular customer             3
# 13        1  Regular customer             3
# 14        1  Regular customer             3
# 15        1  Regular customer             3
# 16        1  Regular customer             4
# 17        1  Regular customer             4
# 18        1  Regular customer             4
# 19        1  Regular customer             4
# 20        1  Regular customer             4
# 21        1  Regular customer             5
# 22        1  Regular customer             5
# 23        1  Regular customer             5
# 24        1  Regular customer             5
# 25        1  Regular customer             5
# 26        1  Regular customer             5
# 27        1  Regular customer             5
# 28        1  Regular customer             5
# 29        1  Regular customer             6
# 30        1  Regular customer             6
# 31        1  Regular customer             6
# 32        1  Regular customer             6
# 33        1  Regular customer             7
# 34        1  Regular customer             7
# 35        1  Regular customer             7
# 36        1  Regular customer             7
# 37        1  Regular customer             7
# 38        1  Regular customer             8
# 39        1  Regular customer             8
# 40        1  Regular customer             8
# 41        1  Regular customer             8
# 42        1  Regular customer             8
# 43        1  Regular customer             8
# 44        1  Regular customer             9
# 45        1  Regular customer             9
# 46        1  Regular customer             9
# 47        1  Regular customer             9
# 48        1  Regular customer             9
# 49        1  Regular customer             9
# 50        1  Regular customer            10
# 51        1  Regular customer            10
# 52        1  Regular customer            10
# 53        1  Regular customer            10
# 54        1  Regular customer            10
# 55        1  Regular customer            10
# 56        1  Regular customer            10
# 57        1  Regular customer            10
# 58        1  Regular customer            10
# 59        1  Regular customer            11

# %% [markdown]
# # 4.8 Answers

# %%
#2
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              15.457838
# 2.0              17.277920
# 3.0              17.170395
# 4.0              17.811403
# 5.0              15.215751
# 6.0              16.439806
# 7.0              17.225802
# 8.0              15.340650
# 9.0              15.895474
# 10.0             20.197148
# 11.0             16.170638
# 12.0             15.887671
# 13.0             16.583536
# 14.0             16.773669
# 15.0             16.165037
# 16.0             17.665606
# 17.0             15.694469
# 18.0             19.310397
# 19.0             17.177343
# 20.0             16.473447
# 21.0             22.902379

# %%
#3
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              14.794925
# 2.0              17.085793
# 3.0              17.892742
# 4.0              17.880137
# 5.0              15.108513
# 6.0              15.352869
# 7.0              17.682741
# 8.0              16.496386
# 9.0              15.944846
# 10.0             20.104831
# 11.0             16.483104
# 12.0             15.614125
# 13.0             16.458631
# 14.0             17.523399
# 15.0             15.673392
# 16.0             18.012021
# 17.0             15.842139
# 18.0             19.349156
# 19.0             17.625805
# 20.0             17.113240
# 21.0             22.009038

# %% [markdown]
#   Both sets are extremely similar with the means from the first set being slightly higher. It just shows that both sets reflect the mean of the entire data set fairly well, hence the similarity.

# %%
#4 Done above

# %%
#5
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.377144  1.0  99999.0
# New customer      13.208437  1.0  99999.0
# Regular customer  12.616225  1.0  99999.0

# %% [markdown]
# Suprisingly, the loyal customers spend the least on average. While the new customers spend the most with the regulars not far behind. This could be because the loyal and more regular customers buy items more often, and therefore spend less initally, but more over time?

# %%
#6
ords_prods_merge.groupby('user_id').agg({'prices': ['mean', 'min', 'max']}).head(5)
# Out:
#            prices
#              mean  min   max
# user_id
# 1        6.367797  1.0  14.0
# 2        7.515897  1.3  14.8
# 3        8.197727  1.3  14.4
# 4        8.205556  1.4  14.6
# 5        9.189189  3.2  14.8

# %%
ords_prods_merge['spending'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.loc[ords_prods_merge['spending'] < 10, 'spending_flag'] = 'Low Spender'

# %%
ords_prods_merge.loc[ords_prods_merge['spending'] >= 10, 'spending_flag'] = 'High Spender'

# %%
df_1 = ords_prods_merge[['user_id', 'spending_flag', 'spending']]

# %%
ords_prods_merge[['user_id', 'spending_flag', 'spending']].head(10)
# Out:
#    user_id spending_flag  spending
# 0        1   Low Spender  6.367797
# 1        1   Low Spender  6.367797
# 2        1   Low Spender  6.367797
# 3        1   Low Spender  6.367797
# 4        1   Low Spender  6.367797
# 5        1   Low Spender  6.367797
# 6        1   Low Spender  6.367797
# 7        1   Low Spender  6.367797
# 8        1   Low Spender  6.367797
# 9        1   Low Spender  6.367797

# %%
#7
ords_prods_merge['frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.loc[ords_prods_merge['frequency'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['frequency'] <= 20) & (ords_prods_merge['frequency'] > 10), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['frequency'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge[['user_id', 'frequency', 'frequency_flag']].head(10)
# Out:
#    user_id  frequency    frequency_flag
# 0        1       20.0  Regular customer
# 1        1       20.0  Regular customer
# 2        1       20.0  Regular customer
# 3        1       20.0  Regular customer
# 4        1       20.0  Regular customer
# 5        1       20.0  Regular customer
# 6        1       20.0  Regular customer
# 7        1       20.0  Regular customer
# 8        1       20.0  Regular customer
# 9        1       20.0  Regular customer

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','4.3_orders_products', '4.8_ords_prods_merge.pkl'))
