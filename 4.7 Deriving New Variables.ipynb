# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
#1
df_ords_prods_merge = pd.read_pickle(r'C:\Users\Riley\Desktop\Data Any\DD-MM-2022-Instacart Basket Analysis\02 Data\4.3_orders_products\orders_products_merged.pkl')

# %%
path = r'C:\Users\Riley\Desktop\Data Any\DD-MM-2022-Instacart Basket Analysis'

# %%
# Created subset
df = df_ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 15)

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN       196.0                1.0
# 1                  8                     NaN     14084.0                2.0
# 2                  8                     NaN     12427.0                3.0
# 3                  8                     NaN     26088.0                4.0
# 4                  8                     NaN     26405.0                5.0
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\Riley\AppData\Local\Temp/ipykernel_5208/2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts (dropna = False)
# Out:
# Mid-range product    668114
# Low-range product    312168
# High range            12340
# Not enough data        7378
# Name: price_range, dtype: int64

# %%
# max() function
df['prices'].max()
# Out:
# 99999.0

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\Riley\anaconda3\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\Riley\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     668114
# Low-range product     312168
# High-range product     12340
# NaN                     7378
# Name: price_range_loc, dtype: int64

# %%
# If-Statements with the loc() Function
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['prices'] <= 15) & (df_ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# NaN                     236409
# Name: price_range_loc, dtype: int64

# %%
# If-Statements with For-Loops
df_ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6252941
# 1    5696724
# 6    4530304
# 2    4243173
# 5    4236989
# 3    3868747
# 4    3812390
# Name: orders_day_of_week, dtype: int64

# %%
result = []

for value in df_ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_ords_prods_merge['busiest_day'] = result

# %%
df_ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22575937
# Busiest day        6252941
# Least busy         3812390
# Name: busiest_day, dtype: int64

# %% [markdown]
# # 4.7 Answers

# %%
#2
df_ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6252941
# 1    5696724
# 6    4530304
# 2    4243173
# 5    4236989
# 3    3868747
# 4    3812390
# Name: orders_day_of_week, dtype: int64

# %%
result = []

for value in df_ords_prods_merge["orders_day_of_week"]:
  if value == 0 and value == 1:
    result.append("Busiest day")
  elif value == 3 and value == 4:
    result.append("Slowest days")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_ords_prods_merge['Busiest_days'] = result

# %%
df_ords_prods_merge['Busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    32641268
# Name: Busiest_days, dtype: int64

# %%
#3 Suprisingly, there isn't any diffeence between the slowest and busiest days in the chart, but there is a large difference 
# in the value counts in the cell above.
df_ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN       196.0                1.0
# 1                  8                     NaN     14084.0                2.0
# 2                  8                     NaN     12427.0                3.0
# 3                  8                     NaN     26088.0                4.0
# 4                  8                     NaN     26405.0                5.0
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
#4 10 am seems to be the busiest time of the day
df_ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2781009
# 11    2755369
# 14    2709084
# 15    2682090
# 13    2680171
# 12    2637533
# 16    2554110
# 9     2471067
# 17    2104225
# 8     1729871
# 18    1649870
# 19    1268365
# 20     983232
# 7      897163
# 21     801052
# 22     638671
# 23     405051
# 6      292533
# 0      220337
# 1      116589
# 5       88661
# 2       69904
# 4       53636
# 3       51675
# Name: order_hour_of_day, dtype: int64

# %%
result = []

for value in df_ords_prods_merge["order_hour_of_day"]:
  if value == 10:
    result.append("Most orders")
  elif value == 13:
    result.append("Average orders")
  else:
    result.append("Fewest orders")

# %%
result
# Out:
# ['Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
# ...

# %%
df_ords_prods_merge['busiest_period_of_day'] = result

# %%
df_ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Fewest orders     27180088
# Most orders        2781009
# Average orders     2680171
# Name: busiest_period_of_day, dtype: int64

# %%
#5 Printed Frequency
df_ords_prods_merge['busiest_period_of_day']
# Out:
# 0           Fewest orders
# 1           Fewest orders
# 2           Fewest orders
# 3           Fewest orders
# 4           Fewest orders
#                 ...
# 32641263    Fewest orders
# 32641264    Fewest orders
# 32641265    Fewest orders
# 32641266    Fewest orders
# 32641267    Fewest orders
# Name: busiest_period_of_day, Length: 32641268, dtype: object

# %%
#6 Done

# %%
#7 
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','4.3_orders_products', '4.7_orders_products_merge_Deriving_New.pkl'))
